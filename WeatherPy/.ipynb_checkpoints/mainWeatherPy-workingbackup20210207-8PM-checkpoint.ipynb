# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\mbarr\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\mbarr\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

import json

from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %%
# display cities
cities
# Out:
# ['busselton',
#  'liverpool',
#  'port blair',
#  'sobolevo',
#  'caravelas',
#  'bulungu',
#  'castro',
#  'bredasdorp',
#  'hermanus',
#  'nizwa',
#  'coihaique',
#  'paamiut',
#  'lancaster',
#  'hilo',
#  'arraial do cabo',
#  'beringovskiy',
#  'longyearbyen',
#  'baghdad',
#  'howard springs',
#  'cape town',
#  'samusu',
#  'ilulissat',
#  'punta arenas',
#  'khatanga',
#  'marawi',
#  'tsihombe',
#  'derzhavinsk',
#  'qaanaaq',
#  'rio grande',
#  'makung',
#  'kapaa',
#  'sitka',
#  'gat',
#  'perelyub',
#  'srednekolymsk',
#  'hobart',
#  'walvis bay',
#  'mar del plata',
#  'souillac',
#  'andenes',
#  'emba',
#  'zeya',
#  'diego de almagro',
#  'illoqqortoormiut',
#  'lorengau',
#  'lompoc',
#  'east london',
#  'cayenne',
#  'yarim',
#  'albany',
#  'mitu',
#  'salekhard',
#  'rikitea',
#  'te anau',
#  'port lincoln',
#  'atuona',
#  'maraba',
#  'taolanaro',
#  'yellowknife',
#  'aleksandrovskiy zavod',
#  'feijo',
#  'torbay',
#  'dudinka',
#  'vero beach',
#  'guarapari',
#  'ribeira grande',
#  'mataura',
#  'ushuaia',
#  'tuktoyaktuk',
#  'ahipara',
#  'carnarvon',
#  'jampur',
#  'lebu',
#  'vila velha',
#  'belushya guba',
#  'tulcingo',
#  'jumla',
#  'fortuna',
#  'batticaloa',
#  'airai',
#  'vaitape',
#  'zhangjiakou',
#  'hutchinson',
#  'panalingaan',
#  'gamba',
#  'georgetown',
#  'bambous virieux',
#  'half moon bay',
#  'jamestown',
#  'kotli loharan',
#  'cuamba',
#  'ngatea',
#  'berezovyy',
#  'bethel',
#  'new norfolk',
#  'simao',
#  'walkerton',
#  'butaritari',
#  'provideniya',
#  'shimoda',
#  'clyde river',
#  'vaitupu',
#  'norman wells',
#  'luderitz',
#  'pinega',
#  'bubaque',
#  'severo-kurilsk',
#  'novikovo',
#  'berlevag',
#  'naryan-mar',
#  'jawhar',
#  'hovd',
#  'mastic beach',
#  'cidreira',
#  'deputatskiy',
#  'meyungs',
#  'komsomolskiy',
#  'buala',
#  'hithadhoo',
#  'chuy',
#  'potoci',
#  'araouane',
#  'port alfred',
#  'marcona',
#  'meulaboh',
#  'vestmannaeyjar',
#  'neiafu',
#  'avarua',
#  'chokurdakh',
#  'victoria',
#  'saint-philippe',
#  'nago',
#  'male',
#  'haines junction',
#  'karaman',
#  'shizunai',
#  'vagur',
#  'moses lake',
#  'bluff',
#  'viedma',
#  'lagoa',
#  'hay river',
#  'buckeye',
#  'arman',
#  'faanui',
#  'chandbali',
#  'honningsvag',
#  'goderich',
#  'beyneu',
#  'mys shmidta',
#  'barrow',
#  'tumannyy',
#  'bay roberts',
#  'alice springs',
#  'thompson',
#  'vaini',
#  'hamilton',
#  'buin',
#  'magura ilvei',
#  'saint anthony',
#  'dikson',
#  'kaitangata',
#  'vila franca do campo',
#  'port elizabeth',
#  'nikolskoye',
#  'dingle',
#  'lamu',
#  'udachnyy',
#  'shaunavon',
#  'grand centre',
#  'puerto ayora',
#  'lisala',
#  'grand river south east',
#  'barentsburg',
#  'aksarka',
#  'launceston',
#  'luganville',
#  'planaltina',
#  'shingu',
#  'vanimo',
#  'virginia beach',
#  'batemans bay',
#  'morris',
#  'aflu',
#  'lavrentiya',
#  'natal',
#  'oarai',
#  'diamantino',
#  'dalmau',
#  'boueni',
#  'roald',
#  'belomorsk',
#  'karratha',
#  'nizhneyansk',
#  'powell river',
#  'southampton',
#  'nakhon phanom',
#  'miles city',
#  'high level',
#  'mango',
#  'la ronge',
#  'naze',
#  'oistins',
#  'maniitsoq',
#  'vardo',
#  'ancud',
#  'timra',
#  'vaxjo',
#  'san cristobal',
#  'saint george',
#  'dourbali',
#  'nouadhibou',
#  'taoudenni',
#  'makakilo city',
#  'oriximina',
#  'san quintin',
#  'madang',
#  'mehamn',
#  'tuatapere',
#  'teguise',
#  'geraldton',
#  'yumen',
#  'ponta do sol',
#  'ifakara',
#  'pitimbu',
#  'tabuk',
#  'guozhen',
#  'arlit',
#  'neryungri',
#  'kushmurun',
#  'aripuana',
#  'wagar',
#  'ulaangom',
#  'mabaruma',
#  'burgeo',
#  'hami',
#  'okhansk',
#  'upernavik',
#  'houlung',
#  'labutta',
#  'namatanai',
#  'kununurra',
#  'corinto',
#  'marsh harbour',
#  'vostok',
#  'srikakulam',
#  'ituni',
#  'severodvinsk',
#  'katsuura',
#  'sur',
#  'resistencia',
#  'boa viagem',
#  'sarankhola',
#  'mayo',
#  'narsaq',
#  'henties bay',
#  'moron',
#  'uruzgan',
#  'korla',
#  'sarangani',
#  'hof',
#  'toliary',
#  'atar',
#  'rungata',
#  'hofn',
#  'saint-joseph',
#  'jabiru',
#  'jalu',
#  'puerto carreno',
#  'marzuq',
#  'tasiilaq',
#  'kuching',
#  'wattegama',
#  'pisco',
#  'chalchihuites',
#  'bengkulu',
#  'shirokiy',
#  'razole',
#  'ulladulla',
#  'sinnamary',
#  'storforshei',
#  'krasnoselkup',
#  'khasan',
#  'nara',
#  'mentok',
#  'krasnogorskoye',
#  'nioro',
#  'natchitoches',
#  'tual',
#  'leningradskiy',
#  'aybak',
#  'klaksvik',
#  'tokur',
#  'bathsheba',
#  'comodoro rivadavia',
#  'ust-kuyga',
#  'lata',
#  'ilorin',
#  'uwayl',
#  'turbat',
#  'markha',
#  'akdepe',
#  'harper',
#  'fevralsk',
#  'fare',
#  'poum',
#  'tamandare',
#  'najran',
#  'changli',
#  'playa vicente',
#  'doctor pedro p. pena',
#  'silvassa',
#  'karpathos',
#  'paso de carrasco',
#  'pevek',
#  'porto novo',
#  'attawapiskat',
#  'iqaluit',
#  'reinosa',
#  'kavaratti',
#  'pacific grove',
#  'ostersund',
#  'grenada',
#  'codrington',
#  'pangnirtung',
#  'cockburn town',
#  'okha',
#  'fort nelson',
#  'mogadishu',
#  'aklavik',
#  'terra santa',
#  'yulara',
#  'arica',
#  'guerrero negro',
#  'santa cruz',
#  'otradnoye',
#  'luwuk',
#  'dolores',
#  'nalut',
#  'faya',
#  'mincivan',
#  'kecel',
#  'sabang',
#  'thunder bay',
#  'brigantine',
#  'galesong',
#  'necochea',
#  'saint-augustin',
#  'kamenka',
#  'jibuti',
#  'iralaya',
#  'sao joao da barra',
#  'amderma',
#  'ostrovnoy',
#  'namibe',
#  'saskylakh',
#  'kodiak',
#  'nanchang',
#  'mahebourg',
#  'hyeres',
#  'kaeo',
#  'beloha',
#  'sangar',
#  'bjornevatn',
#  'chara',
#  'batagay-alyta',
#  'manihari',
#  'svetlogorsk',
#  'anadyr',
#  'mount isa',
#  'haian',
#  'santa maria del oro',
#  'gusau',
#  'mandalgovi',
#  'zemio',
#  'palabuhanratu',
#  'sioux lookout',
#  'gayeri',
#  'leh',
#  'ninove',
#  'katherine',
#  'general pico',
#  'viligili',
#  'jaipur hat',
#  'kharp',
#  'kruisfontein',
#  'carutapera',
#  'sayyan',
#  'chivilcoy',
#  'svetlyy',
#  'sao filipe',
#  'gazojak',
#  'ixtapa',
#  'samarai',
#  'broome',
#  'manacapuru',
#  'haputale',
#  'rio gallegos',
#  'penzance',
#  'satinka',
#  'san rafael',
#  'alofi',
#  'ngukurr',
#  'sola',
#  'muroto',
#  'dongen',
#  'nemuro',
#  'paradwip',
#  'dicabisagan',
#  'ondorhaan',
#  'nabire',
#  'asyut',
#  'mount gambier',
#  'tateyama',
#  'mackenzie',
#  'west wendover',
#  'noumea',
#  'tome-acu',
#  'bushehr',
#  'chardara',
#  'seoul',
#  'amapa',
#  'nacala',
#  'avera',
#  'aracati',
#  'watrous',
#  'chapais',
#  'sept-iles',
#  'ubrique',
#  'tabas',
#  'kuala terengganu',
#  'kokopo',
#  'boca do acre',
#  'carapicuiba',
#  'esperance',
#  'krasnogvardeyskiy',
#  'morros',
#  'borogontsy',
#  'flinders',
#  'sosnogorsk',
#  'cherskiy',
#  'manaure',
#  'khandyga',
#  'shubarshi',
#  'port hardy',
#  'rapid valley',
#  'manzhouli',
#  'zhicheng',
#  'lolua',
#  'la rioja',
#  'millinocket',
#  'rolim de moura',
#  'rio de jesus',
#  'kirovskiy',
#  'zabaykalsk',
#  'maragogi',
#  'decatur',
#  'tandalti',
#  'karoi',
#  'praia da vitoria',
#  'aswan',
#  'popondetta',
#  'mazamari',
#  'manta',
#  'san patricio',
#  'margate',
#  'camana',
#  'sentyabrskiy',
#  'tepelene',
#  'westport',
#  'altamira',
#  'rio branco',
#  'dwarka',
#  'makat',
#  'baykit',
#  'wanning',
#  'pimentel',
#  'kawalu',
#  'panlaitan',
#  'pozo colorado',
#  'kysyl-syr',
#  'coquimbo',
#  'zhigansk',
#  'lethem',
#  'antalaha',
#  'nelson bay',
#  'umm lajj',
#  'laguna de perlas',
#  'morehead',
#  'tena',
#  'tiksi',
#  'banda aceh',
#  'goteborg',
#  'ocos',
#  'nokha',
#  'saleaula',
#  'tautira',
#  'ipira',
#  'ahuimanu',
#  'bima',
#  'sinjar',
#  'havre-saint-pierre',
#  'puteyets',
#  'louisbourg',
#  'kuytun',
#  'hambantota',
#  'kyaikkami',
#  'balaka',
#  'el jicaro',
#  'jose de freitas',
#  'kalianget',
#  'bend',
#  'cabo san lucas',
#  'bonthe',
#  'filadelfia',
#  'terney',
#  'rauma',
#  'nyurba',
#  'adrar',
#  'svelgen',
#  'taos',
#  'saldanha',
#  'mlonggo',
#  'maiduguri',
#  'evans',
#  'touros',
#  'kabugao',
#  'giaginskaya',
#  'bolungarvik',
#  'palembang',
#  'sidney',
#  'dauphin',
#  'bilibino',
#  'safaqis',
#  'nusaybin',
#  'fairbanks',
#  'vao',
#  'nome',
#  'muzhi',
#  'mizpe ramon',
#  'progreso',
#  'tezu',
#  'cedar city',
#  'samalaeulu',
#  'lingao',
#  'cap malheureux',
#  'mao',
#  'rocha',
#  'trincomalee',
#  'pitea',
#  'ransang',
#  'huarmey',
#  'tura',
#  'youghal',
#  'isangel',
#  'lishui',
#  'vila',
#  'mujiayingzi',
#  'kimbe',
#  'kahramanmaras',
#  'rawannawi',
#  'acapulco',
#  'constitucion',
#  'biltine',
#  'concordia',
#  'nuuk',
#  'ossora',
#  'solnechnyy',
#  'ilmajoki',
#  'muros',
#  'svetlaya',
#  'grand-lahou',
#  'hasaki',
#  'tilichiki',
#  'fayetteville',
#  'auki',
#  'mbini',
#  'prieska',
#  'zhezkazgan',
#  'salinopolis',
#  'scottsburgh',
#  'kamskoye ustye',
#  'beaverlodge',
#  'nokaneng',
#  'ballina',
#  'ambam',
#  'chicama',
#  'asayita',
#  'egvekinot',
#  'datong',
#  'tonantins',
#  'same']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# -- do not use or run -- keep for reference on expected result

# %%
### Perform API Calls

####  TEMP for testing only:
city_name= 'yulara'

url=(f'https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={weather_api_key}')
url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=yulara&appid=d64f2833aec28689f5af36a76f9fa491'

# %%
url=(f'https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={weather_api_key}')
url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=yulara&appid=d64f2833aec28689f5af36a76f9fa491'

# %%
# Pretty print JSON for weather
response = requests.get(url).json()

print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 14
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -25.2406,
#         "lon": 130.9889
#     },
#     "dt": 1612743105,
#     "id": 6355222,
#     "main": {
#         "feels_like": 296.68,
#         "humidity": 21,
#         "pressure": 1010,
#         "temp": 303.15,
#         "temp_max": 303.15,
#         "temp_min": 303.15
#     },
#     "name": "Yulara",
#     "sys": {
#         "country": "AU",
#         "id": 9487,
#         "sunrise": 1612731439,
#         "sunset": 1612778592,
#         "type": 1
#     },
#     "timezone": 34200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 80,
#         "speed": 7.72
#     }
# }

# %%
# reference only -- # List for holding lat_lngs and cities
# cities = []

lat_lngs = []

for city in cities:
    url=(f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}')
    response = requests.get(url).json()
    
    try:
        lat = response["coord"]["lat"]
        long = response["coord"]["lon"]

        lat_lng = {'latitude':lat,
                   'longitude':long}

        print("lat", lat, "long", long)
    except:
        continue

    lat_lngs.append(lat_lng)
    
lat_lngs

# %%
#### reference only for expected results   
lat_lngs
# Out:
# [{'latitude': -33.65, 'longitude': 115.3333},
#  {'latitude': 53.4106, 'longitude': -2.9779},
#  {'latitude': 11.6667, 'longitude': 92.75},
#  {'latitude': -46.1927, 'longitude': 168.8643},
#  {'latitude': -54.8, 'longitude': -68.3},
#  {'latitude': 69.4541, 'longitude': -133.0374},
#  {'latitude': -35.1667, 'longitude': 173.1667},
#  {'latitude': -24.8667, 'longitude': 113.6333},
#  {'latitude': 29.6441, 'longitude': 70.5954},
#  {'latitude': -37.6167, 'longitude': -73.65},
#  {'latitude': -20.3297, 'longitude': -40.2925}]

# %%
# display cities
cities
# Out:
# ['busselton',
#  'liverpool',
#  'port blair',
#  'sobolevo',
#  'caravelas',
#  'bulungu',
#  'castro',
#  'bredasdorp',
#  'hermanus',
#  'nizwa',
#  'coihaique',
#  'paamiut',
#  'lancaster',
#  'hilo',
#  'arraial do cabo',
#  'beringovskiy',
#  'longyearbyen',
#  'baghdad',
#  'howard springs',
#  'cape town',
#  'samusu',
#  'ilulissat',
#  'punta arenas',
#  'khatanga',
#  'marawi',
#  'tsihombe',
#  'derzhavinsk',
#  'qaanaaq',
#  'rio grande',
#  'makung',
#  'kapaa',
#  'sitka',
#  'gat',
#  'perelyub',
#  'srednekolymsk',
#  'hobart',
#  'walvis bay',
#  'mar del plata',
#  'souillac',
#  'andenes',
#  'emba',
#  'zeya',
#  'diego de almagro',
#  'illoqqortoormiut',
#  'lorengau',
#  'lompoc',
#  'east london',
#  'cayenne',
#  'yarim',
#  'albany',
#  'mitu',
#  'salekhard',
#  'rikitea',
#  'te anau',
#  'port lincoln',
#  'atuona',
#  'maraba',
#  'taolanaro',
#  'yellowknife',
#  'aleksandrovskiy zavod',
#  'feijo',
#  'torbay',
#  'dudinka',
#  'vero beach',
#  'guarapari',
#  'ribeira grande',
#  'mataura',
#  'ushuaia',
#  'tuktoyaktuk',
#  'ahipara',
#  'carnarvon',
#  'jampur',
#  'lebu',
#  'vila velha',
#  'belushya guba',
#  'tulcingo',
#  'jumla',
#  'fortuna',
#  'batticaloa',
#  'airai',
#  'vaitape',
#  'zhangjiakou',
#  'hutchinson',
#  'panalingaan',
#  'gamba',
#  'georgetown',
#  'bambous virieux',
#  'half moon bay',
#  'jamestown',
#  'kotli loharan',
#  'cuamba',
#  'ngatea',
#  'berezovyy',
#  'bethel',
#  'new norfolk',
#  'simao',
#  'walkerton',
#  'butaritari',
#  'provideniya',
#  'shimoda',
#  'clyde river',
#  'vaitupu',
#  'norman wells',
#  'luderitz',
#  'pinega',
#  'bubaque',
#  'severo-kurilsk',
#  'novikovo',
#  'berlevag',
#  'naryan-mar',
#  'jawhar',
#  'hovd',
#  'mastic beach',
#  'cidreira',
#  'deputatskiy',
#  'meyungs',
#  'komsomolskiy',
#  'buala',
#  'hithadhoo',
#  'chuy',
#  'potoci',
#  'araouane',
#  'port alfred',
#  'marcona',
#  'meulaboh',
#  'vestmannaeyjar',
#  'neiafu',
#  'avarua',
#  'chokurdakh',
#  'victoria',
#  'saint-philippe',
#  'nago',
#  'male',
#  'haines junction',
#  'karaman',
#  'shizunai',
#  'vagur',
#  'moses lake',
#  'bluff',
#  'viedma',
#  'lagoa',
#  'hay river',
#  'buckeye',
#  'arman',
#  'faanui',
#  'chandbali',
#  'honningsvag',
#  'goderich',
#  'beyneu',
#  'mys shmidta',
#  'barrow',
#  'tumannyy',
#  'bay roberts',
#  'alice springs',
#  'thompson',
#  'vaini',
#  'hamilton',
#  'buin',
#  'magura ilvei',
#  'saint anthony',
#  'dikson',
#  'kaitangata',
#  'vila franca do campo',
#  'port elizabeth',
#  'nikolskoye',
#  'dingle',
#  'lamu',
#  'udachnyy',
#  'shaunavon',
#  'grand centre',
#  'puerto ayora',
#  'lisala',
#  'grand river south east',
#  'barentsburg',
#  'aksarka',
#  'launceston',
#  'luganville',
#  'planaltina',
#  'shingu',
#  'vanimo',
#  'virginia beach',
#  'batemans bay',
#  'morris',
#  'aflu',
#  'lavrentiya',
#  'natal',
#  'oarai',
#  'diamantino',
#  'dalmau',
#  'boueni',
#  'roald',
#  'belomorsk',
#  'karratha',
#  'nizhneyansk',
#  'powell river',
#  'southampton',
#  'nakhon phanom',
#  'miles city',
#  'high level',
#  'mango',
#  'la ronge',
#  'naze',
#  'oistins',
#  'maniitsoq',
#  'vardo',
#  'ancud',
#  'timra',
#  'vaxjo',
#  'san cristobal',
#  'saint george',
#  'dourbali',
#  'nouadhibou',
#  'taoudenni',
#  'makakilo city',
#  'oriximina',
#  'san quintin',
#  'madang',
#  'mehamn',
#  'tuatapere',
#  'teguise',
#  'geraldton',
#  'yumen',
#  'ponta do sol',
#  'ifakara',
#  'pitimbu',
#  'tabuk',
#  'guozhen',
#  'arlit',
#  'neryungri',
#  'kushmurun',
#  'aripuana',
#  'wagar',
#  'ulaangom',
#  'mabaruma',
#  'burgeo',
#  'hami',
#  'okhansk',
#  'upernavik',
#  'houlung',
#  'labutta',
#  'namatanai',
#  'kununurra',
#  'corinto',
#  'marsh harbour',
#  'vostok',
#  'srikakulam',
#  'ituni',
#  'severodvinsk',
#  'katsuura',
#  'sur',
#  'resistencia',
#  'boa viagem',
#  'sarankhola',
#  'mayo',
#  'narsaq',
#  'henties bay',
#  'moron',
#  'uruzgan',
#  'korla',
#  'sarangani',
#  'hof',
#  'toliary',
#  'atar',
#  'rungata',
#  'hofn',
#  'saint-joseph',
#  'jabiru',
#  'jalu',
#  'puerto carreno',
#  'marzuq',
#  'tasiilaq',
#  'kuching',
#  'wattegama',
#  'pisco',
#  'chalchihuites',
#  'bengkulu',
#  'shirokiy',
#  'razole',
#  'ulladulla',
#  'sinnamary',
#  'storforshei',
#  'krasnoselkup',
#  'khasan',
#  'nara',
#  'mentok',
#  'krasnogorskoye',
#  'nioro',
#  'natchitoches',
#  'tual',
#  'leningradskiy',
#  'aybak',
#  'klaksvik',
#  'tokur',
#  'bathsheba',
#  'comodoro rivadavia',
#  'ust-kuyga',
#  'lata',
#  'ilorin',
#  'uwayl',
#  'turbat',
#  'markha',
#  'akdepe',
#  'harper',
#  'fevralsk',
#  'fare',
#  'poum',
#  'tamandare',
#  'najran',
#  'changli',
#  'playa vicente',
#  'doctor pedro p. pena',
#  'silvassa',
#  'karpathos',
#  'paso de carrasco',
#  'pevek',
#  'porto novo',
#  'attawapiskat',
#  'iqaluit',
#  'reinosa',
#  'kavaratti',
#  'pacific grove',
#  'ostersund',
#  'grenada',
#  'codrington',
#  'pangnirtung',
#  'cockburn town',
#  'okha',
#  'fort nelson',
#  'mogadishu',
#  'aklavik',
#  'terra santa',
#  'yulara',
#  'arica',
#  'guerrero negro',
#  'santa cruz',
#  'otradnoye',
#  'luwuk',
#  'dolores',
#  'nalut',
#  'faya',
#  'mincivan',
#  'kecel',
#  'sabang',
#  'thunder bay',
#  'brigantine',
#  'galesong',
#  'necochea',
#  'saint-augustin',
#  'kamenka',
#  'jibuti',
#  'iralaya',
#  'sao joao da barra',
#  'amderma',
#  'ostrovnoy',
#  'namibe',
#  'saskylakh',
#  'kodiak',
#  'nanchang',
#  'mahebourg',
#  'hyeres',
#  'kaeo',
#  'beloha',
#  'sangar',
#  'bjornevatn',
#  'chara',
#  'batagay-alyta',
#  'manihari',
#  'svetlogorsk',
#  'anadyr',
#  'mount isa',
#  'haian',
#  'santa maria del oro',
#  'gusau',
#  'mandalgovi',
#  'zemio',
#  'palabuhanratu',
#  'sioux lookout',
#  'gayeri',
#  'leh',
#  'ninove',
#  'katherine',
#  'general pico',
#  'viligili',
#  'jaipur hat',
#  'kharp',
#  'kruisfontein',
#  'carutapera',
#  'sayyan',
#  'chivilcoy',
#  'svetlyy',
#  'sao filipe',
#  'gazojak',
#  'ixtapa',
#  'samarai',
#  'broome',
#  'manacapuru',
#  'haputale',
#  'rio gallegos',
#  'penzance',
#  'satinka',
#  'san rafael',
#  'alofi',
#  'ngukurr',
#  'sola',
#  'muroto',
#  'dongen',
#  'nemuro',
#  'paradwip',
#  'dicabisagan',
#  'ondorhaan',
#  'nabire',
#  'asyut',
#  'mount gambier',
#  'tateyama',
#  'mackenzie',
#  'west wendover',
#  'noumea',
#  'tome-acu',
#  'bushehr',
#  'chardara',
#  'seoul',
#  'amapa',
#  'nacala',
#  'avera',
#  'aracati',
#  'watrous',
#  'chapais',
#  'sept-iles',
#  'ubrique',
#  'tabas',
#  'kuala terengganu',
#  'kokopo',
#  'boca do acre',
#  'carapicuiba',
#  'esperance',
#  'krasnogvardeyskiy',
#  'morros',
#  'borogontsy',
#  'flinders',
#  'sosnogorsk',
#  'cherskiy',
#  'manaure',
#  'khandyga',
#  'shubarshi',
#  'port hardy',
#  'rapid valley',
#  'manzhouli',
#  'zhicheng',
#  'lolua',
#  'la rioja',
#  'millinocket',
#  'rolim de moura',
#  'rio de jesus',
#  'kirovskiy',
#  'zabaykalsk',
#  'maragogi',
#  'decatur',
#  'tandalti',
#  'karoi',
#  'praia da vitoria',
#  'aswan',
#  'popondetta',
#  'mazamari',
#  'manta',
#  'san patricio',
#  'margate',
#  'camana',
#  'sentyabrskiy',
#  'tepelene',
#  'westport',
#  'altamira',
#  'rio branco',
#  'dwarka',
#  'makat',
#  'baykit',
#  'wanning',
#  'pimentel',
#  'kawalu',
#  'panlaitan',
#  'pozo colorado',
#  'kysyl-syr',
#  'coquimbo',
#  'zhigansk',
#  'lethem',
#  'antalaha',
#  'nelson bay',
#  'umm lajj',
#  'laguna de perlas',
#  'morehead',
#  'tena',
#  'tiksi',
#  'banda aceh',
#  'goteborg',
#  'ocos',
#  'nokha',
#  'saleaula',
#  'tautira',
#  'ipira',
#  'ahuimanu',
#  'bima',
#  'sinjar',
#  'havre-saint-pierre',
#  'puteyets',
#  'louisbourg',
#  'kuytun',
#  'hambantota',
#  'kyaikkami',
#  'balaka',
#  'el jicaro',
#  'jose de freitas',
#  'kalianget',
#  'bend',
#  'cabo san lucas',
#  'bonthe',
#  'filadelfia',
#  'terney',
#  'rauma',
#  'nyurba',
#  'adrar',
#  'svelgen',
#  'taos',
#  'saldanha',
#  'mlonggo',
#  'maiduguri',
#  'evans',
#  'touros',
#  'kabugao',
#  'giaginskaya',
#  'bolungarvik',
#  'palembang',
#  'sidney',
#  'dauphin',
#  'bilibino',
#  'safaqis',
#  'nusaybin',
#  'fairbanks',
#  'vao',
#  'nome',
#  'muzhi',
#  'mizpe ramon',
#  'progreso',
#  'tezu',
#  'cedar city',
#  'samalaeulu',
#  'lingao',
#  'cap malheureux',
#  'mao',
#  'rocha',
#  'trincomalee',
#  'pitea',
#  'ransang',
#  'huarmey',
#  'tura',
#  'youghal',
#  'isangel',
#  'lishui',
#  'vila',
#  'mujiayingzi',
#  'kimbe',
#  'kahramanmaras',
#  'rawannawi',
#  'acapulco',
#  'constitucion',
#  'biltine',
#  'concordia',
#  'nuuk',
#  'ossora',
#  'solnechnyy',
#  'ilmajoki',
#  'muros',
#  'svetlaya',
#  'grand-lahou',
#  'hasaki',
#  'tilichiki',
#  'fayetteville',
#  'auki',
#  'mbini',
#  'prieska',
#  'zhezkazgan',
#  'salinopolis',
#  'scottsburgh',
#  'kamskoye ustye',
#  'beaverlodge',
#  'nokaneng',
#  'ballina',
#  'ambam',
#  'chicama',
#  'asayita',
#  'egvekinot',
#  'datong',
#  'tonantins',
#  'same']

# %%
# export the city data to a csv file
import csv

# Specify the file to write to
output_path = "output_data/cities_file.csv"

# %%
# full run of cities

# Open the file using "write" mode. Specify the variable to hold the contents
with open(output_path, 'w', newline='') as csvfile:

    # Initialize csv.writer
    csvwriter = csv.writer(csvfile, delimiter=',')

    # Write the first row (column headers)
    csvwriter.writerow(['City ID', 'City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 
                        'Max Temp', 'Wind Speed'])
    
    # read cities file, get all the values from the API response and write rows to the cities_file
    
    for city in cities:
        url=(f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}')
        response = requests.get(url).json()
        try:
            city_id = response["sys"]["id"]
            cloudiness = response["clouds"]["all"]
            country = response["sys"]["country"]
            date = response["dt"]
            humidity = response["main"]["humidity"]
            lat = response["coord"]["lat"]
            long = response["coord"]["lon"]
            max_temp = response["main"]["temp_max"]
            wind_speed = response["wind"]["speed"]
            print(city_id, city, cloudiness, country, date, humidity, lat, long, max_temp, wind_speed)
            csvwriter.writerow([city_id, city, cloudiness, country, date, humidity, lat, long, max_temp, wind_speed])
        except:
            continue
# Out:
# 2008303 busselton 81 AU 1612743811 99 -33.65 115.3333 291.48 0.89
# 9362 mlonggo 75 ID 1612744022 94 -6.5333 110.7 298.15 1.54
# 3848 evans 1 US 1612744023 71 33.5337 -82.1307 282.15 1.73
# 8452 touros 40 BR 1612744024 78 -5.1989 -35.4608 300.15 5.14
# 9424 palembang 20 ID 1612743922 94 -2.9167 104.7458 298.15 3.6
# 9600 sidney 75 AU 1612743761 78 -33.8679 151.2073 294.26 7.72
# 780 dauphin 1 CA 1612744026 57 51.1494 -100.0502 243.15 9.26
# 7607 nusaybin 0 TR 1612744027 70 37.0778 41.2178 279.15 1.54
# 7683 fairbanks 20 US 1612743957 70 64.8378 -147.7164 253.71 3.09
# 7770 nome 1 US 1612744028 84 64.5011 -165.4064 255.93 1.59
# 7140 progreso 20 MX 1612744030 78 21.2833 -89.6667 298.71 3.6
# 3584 cedar city 1 US 1612743863 7 37.6775 -113.0619 286.15 3.6
# 2002134 cap malheureux 45 MU 1612744032 84 -19.9842 57.6142 298.71 1.34
# 6422 mao 0 ES 1612744032 71 39.8885 4.2658 283.15 4.12
# 1775 pitea 75 SE 1612744033 92 65.3172 21.4794 264.15 3.6
# 1563 youghal 90 IE 1612744035 69 51.95 -7.8506 276.48 9.26
# 7317 isangel 40 VU 1612744035 74 -19.55 169.2667 302.15 3.09
# 2007751 vila 100 PT 1612744036 95 42.0304 -8.1588 280.93 8.94
# 7002 kahramanmaras 0 TR 1612744037 76 38 37 282.15 1.03
# 7103 acapulco 1 MX 1612744018 74 16.8634 -99.8901 301.15 4.12
# 2016451 concordia 0 AR 1612744039 64 -31.393 -58.0209 299.82 1.28
# 86 nuuk 46 GL 1612744040 43 64.1835 -51.7216 272.15 1.03
# 1358 ilmajoki 1 FI 1612744041 85 62.7333 22.5667 259.26 0.51
# 2000018 muros 86 ES 1612744041 83 42.7762 -9.0603 285.37 1.34
# 7955 hasaki 75 JP 1612743765 52 35.7333 140.8333 278.15 3.09
# 4061 fayetteville 1 US 1612744043 81 35.0527 -78.8784 278.15 1.7
# 2047 mbini 20 GQ 1612744044 100 1.574 9.6134 299.15 3.39
# 9038 kamskoye ustye 75 RU 1612744046 71 55.2016 49.268 251.15 8
# 900 beaverlodge 40 CA 1612744046 68 55.2166 -119.4361 241.15 0.24
# 9496 ballina 72 AU 1612744047 57 -28.8667 153.5667 300.15 8.75

# %% [markdown]
# ##### how to handle timeout
#         except TimeoutError:
#             print("Caught a timeout...")
#             continue

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Cities data file
cities_data_path = "output_data/cities_file.csv"
cities_data_path

# read the cities file and put in a pandas dataframe
cities_df = pd.read_csv(cities_data_path)
cities_df.head()
# Out:
#    City ID        City  Cloudiness Country        Date  Humidity      Lat  \
# 0  2008303   busselton          81      AU  1612743811        99 -33.6500
# 1     1399   liverpool          90      GB  1612743812        60  53.4106
# 2     1966  bredasdorp           7      ZA  1612743727        77 -34.5322
# 3  2006131    hermanus           4      ZA  1612743814        90 -34.4187
# 4     8491   coihaique           0      CL  1612743815        35 -45.5752
#
#         Lng  Max Temp  Wind Speed
# 0  115.3333    291.48        0.89
# 1   -2.9779    275.15        7.72
# 2   20.0403    288.15        2.57
# 3   19.2345    287.04        0.71
# 4  -72.0662    295.15        3.09

# %%
#  temperature conversion & column update

new_df = cities_df

# for testing only ---------------
# maxtemp = 294.26
# temp_f = (maxtemp - 273.15) * 9/5 +32
# temp_f
# --------------------------------

for ind in new_df.index: 
    maxtemp = new_df['Max Temp'][ind]
    temp_f = (maxtemp - 273.15) * 9/5 +32
    new_df['Max Temp'][ind] = temp_f
    print(temp_f)
    print(new_df['Max Temp'][ind], ind) 
new_df
# Out:
# 64.99400000000007
# 64.99400000000007 0
# 35.6
# 35.6 1
# 59.0
# 59.0 2
# 57.00200000000008
# 57.00200000000008 3
# 71.6
# 71.6 4
# 32.0
# 32.0 5
# 80.6
# 80.6 6
# 14.0
# 14.0 7
# 53.6
# 53.6 8
# 82.99400000000007
# 82.99400000000007 9
# 68.0
# 68.0 10
# 19.4
# 19.4 11
# 66.2
# 66.2 12
# 75.00200000000008
# 75.00200000000008 13
# 69.99800000000002
# 69.99800000000002 14
# 75.2
# 75.2 15
# 35.6
# 35.6 16
# 55.004000000000055
# 55.004000000000055 17
# 62.6
# 62.6 18
# 64.99400000000007
# 64.99400000000007 19
# 62.00600000000003
# 62.00600000000003 20
# 78.8
# 78.8 21
# 32.0
# 32.0 22
# 60.998000000000026
# 60.998000000000026 23
# 80.6
# 80.6 24
# 28.004000000000055
# 28.004000000000055 25
# -32.00799999999995
# -32.00799999999995 26
# 30.002000000000077
# 30.002000000000077 27
# 69.99800000000002
# 69.99800000000002 28
# 69.99800000000002
# 69.99800000000002 29
# 51.8
# 51.8 30
# -27.399999999999956
# -27.399999999999956 31
# 80.6
# 80.6 32
# 69.99800000000002
# 69.99800000000002 33
# 53.00600000000003
# 53.00600000000003 34
# 17.6
# 17.6 35
# 80.00600000000003
# 80.00600000000003 36
# 78.8
# 78.8 37
# 64.4
# 64.4 38
# 12.991999999999997
# 12.991999999999997 39
# 50.0
# 50.0 40
# 80.00600000000003
# 80.00600000000003 41
# 28.4
# 28.4 42
# 60.008
# 60.008 43
# 5.0
# 5.0 44
# 51.8
# 51.8 45
# -0.39999999999994884
# -0.39999999999994884 46
# -27.399999999999956
# -27.399999999999956 47
# 30.2
# 30.2 48
# 41.0
# 41.0 49
# 53.6
# 53.6 50
# 64.99400000000007
# 64.99400000000007 51
# 77.0
# 77.0 52
# 84.2
# 84.2 53
# 68.0
# 68.0 54
# 80.6
# 80.6 55
# 66.2
# 66.2 56
# 82.4
# 82.4 57
# -16.59999999999995
# -16.59999999999995 58
# 48.2
# 48.2 59
# 60.008
# 60.008 60
# -30.999999999999957
# -30.999999999999957 61
# 71.6
# 71.6 62
# 12.2
# 12.2 63
# -25.59999999999995
# -25.59999999999995 64
# 30.002000000000077
# 30.002000000000077 65
# 86.0
# 86.0 66
# -25.59999999999995
# -25.59999999999995 67
# 77.0
# 77.0 68
# 19.994000000000074
# 19.994000000000074 69
# 75.2
# 75.2 70
# -2.199999999999946
# -2.199999999999946 71
# 64.99400000000007
# 64.99400000000007 72
# 57.00200000000008
# 57.00200000000008 73
# 64.4
# 64.4 74
:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Max Temp'][ind] = temp_f
#      City ID            City  Cloudiness Country        Date  Humidity  \
# 0    2008303       busselton          81      AU  1612743811        99
# 1       1399       liverpool          90      GB  1612743812        60
# 2       1966      bredasdorp           7      ZA  1612743727        77
# 3    2006131        hermanus           4      ZA  1612743814        90
# 4       8491       coihaique           0      CL  1612743815        35
# ..       ...             ...         ...     ...         ...       ...
# 254     4061    fayetteville           1      US  1612744043        81
# 255     2047           mbini          20      GQ  1612744044       100
# 256     9038  kamskoye ustye          75      RU  1612744046        71
# 257      900     beaverlodge          40      CA  1612744046        68
# 258     9496         ballina          72      AU  1612744047        57
#
#          Lat       Lng  Max Temp  Wind Speed
# 0   -33.6500  115.3333    64.994        0.89
# 1    53.4106   -2.9779    35.600        7.72
# 2   -34.5322   20.0403    59.000        2.57
# 3   -34.4187   19.2345    57.002        0.71
# 4   -45.5752  -72.0662    71.600        3.09
# ..       ...       ...       ...         ...
# 254  35.0527  -78.8784    41.000        1.70
# 255   1.5740    9.6134    78.800        3.39
# 256  55.2016   49.2680    -7.600        8.00
# 257  55.2166 -119.4361   -25.600        0.24
# 258 -28.8667  153.5667    80.600        8.75
#
# [259 rows x 10 columns]

# %%
#  NEED HELP -- date conversion & column update

#testing
#new_df[.to_datetime('1612595343', format='%Y%m%d', errors='ignore')
       
#df['Dates'] = pd.to_datetime(df['Dates'], format='%Y%m%d') 

       
#new_df['Date'] = pd.to_datetime(new_df['Date'], format='%y%m%d', errors='ignore')

new_df['Date'] = pd.to_datetime(1612595343, format='%y%m%d', errors='ignore')

new_df
# Out:
#      City ID            City  Cloudiness Country        Date  Humidity  \
# 0    2008303       busselton          81      AU  1612595343        99
# 1       1399       liverpool          90      GB  1612595343        60
# 2       1966      bredasdorp           7      ZA  1612595343        77
# 3    2006131        hermanus           4      ZA  1612595343        90
# 4       8491       coihaique           0      CL  1612595343        35
# ..       ...             ...         ...     ...         ...       ...
# 254     4061    fayetteville           1      US  1612595343        81
# 255     2047           mbini          20      GQ  1612595343       100
# 256     9038  kamskoye ustye          75      RU  1612595343        71
# 257      900     beaverlodge          40      CA  1612595343        68
# 258     9496         ballina          72      AU  1612595343        57
#
#          Lat       Lng  Max Temp  Wind Speed
# 0   -33.6500  115.3333    64.994        0.89
# 1    53.4106   -2.9779    35.600        7.72
# 2   -34.5322   20.0403    59.000        2.57
# 3   -34.4187   19.2345    57.002        0.71
# 4   -45.5752  -72.0662    71.600        3.09
# ..       ...       ...       ...         ...
# 254  35.0527  -78.8784    41.000        1.70
# 255   1.5740    9.6134    78.800        3.39
# 256  55.2016   49.2680    -7.600        8.00
# 257  55.2166 -119.4361   -25.600        0.24
# 258 -28.8667  153.5667    80.600        8.75
#
# [259 rows x 10 columns]

# %%
# create a subset
subset_cities_df = cities_df[["Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country", "Date"]]
subset_cities_df
# Out:
#          Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed Country  \
# 0   -33.6500  115.3333    64.994        99          81        0.89      AU
# 1    53.4106   -2.9779    35.600        60          90        7.72      GB
# 2   -34.5322   20.0403    59.000        77           7        2.57      ZA
# 3   -34.4187   19.2345    57.002        90           4        0.71      ZA
# 4   -45.5752  -72.0662    71.600        35           0        3.09      CL
# ..       ...       ...       ...       ...         ...         ...     ...
# 254  35.0527  -78.8784    41.000        81           1        1.70      US
# 255   1.5740    9.6134    78.800       100          20        3.39      GQ
# 256  55.2016   49.2680    -7.600        71          75        8.00      RU
# 257  55.2166 -119.4361   -25.600        68          40        0.24      CA
# 258 -28.8667  153.5667    80.600        57          72        8.75      AU
#
#            Date
# 0    1612595343
# 1    1612595343
# 2    1612595343
# 3    1612595343
# 4    1612595343
# ..          ...
# 254  1612595343
# 255  1612595343
# 256  1612595343
# 257  1612595343
# 258  1612595343
#
# [259 rows x 8 columns]

# %%
# Describe the dataframe
subset_cities_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  259.000000  259.000000  259.000000  259.000000  259.000000  259.000000
# mean    19.822500  -11.922422   48.198332   70.861004   42.830116    4.017104
# std     34.794041   92.515652   31.267131   18.480347   36.813300    2.716737
# min    -54.800000 -175.200000  -45.400000    7.000000    0.000000    0.240000
# 25%    -14.175000  -81.923600   30.002000   60.000000    1.000000    2.060000
# 50%     33.283300  -27.066700   55.400000   73.000000   40.000000    3.600000
# 75%     46.827700   47.172050   75.200000   84.000000   75.000000    5.660000
# max     78.218600  177.483300   89.600000  100.000000  100.000000   20.060000
#
#                Date
# count  2.590000e+02
# mean   1.612595e+09
# std    0.000000e+00
# min    1.612595e+09
# 25%    1.612595e+09
# 50%    1.612595e+09
# 75%    1.612595e+09
# max    1.612595e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_humidity_gt_100_df = cities_df[cities_df["Humidity"] >= 100]
cities_humidity_gt_100_df
# Out:
#      City ID        City  Cloudiness Country        Date  Humidity      Lat  \
# 29      8474   guarapari          90      BR  1612595343       100 -20.6667
# 32      9505   carnarvon          40      AU  1612595343       100 -24.8667
# 33      8474  vila velha          90      BR  1612595343       100 -20.3297
# 50      6905      potoci          90      BA  1612595343       100  43.4086
# 84      4940      morris          75      US  1612595343       100  40.8334
# 121     9366     kuching          20      MY  1612595343       100   1.5500
# 122     9124   wattegama           0      LK  1612595343       100   6.7989
# 151     6666       kecel          90      HU  1612595343       100  46.5253
# 173     9124    haputale           0      LK  1612595343       100   6.7681
# 209     8425  rio branco          40      BR  1612595343       100  -9.9747
# 220     9124  hambantota           0      LK  1612595343       100   6.1241
# 255     2047       mbini          20      GQ  1612595343       100   1.5740
#
#           Lng  Max Temp  Wind Speed
# 29   -40.4975    69.998        3.09
# 32   113.6333    80.600        5.66
# 33   -40.2925    69.998        3.09
# 50    17.8786    53.600        2.57
# 84   -74.5329    30.992        2.06
# 121  110.3333    75.200        1.03
# 122   81.4808    73.400        1.03
# 151   19.2519    44.006        4.12
# 173   80.9595    73.400        1.03
# 209  -67.8100    77.000        3.09
# 220   81.1185    73.400        1.03
# 255    9.6134    78.800        3.39

# %%
# Inspect the data and remove the cities where the humidity > 100%

cities_humidity_le_100_df = cities_df

index_names = cities_humidity_le_100_df[ cities_humidity_le_100_df['Humidity'] > 100].index 
  
# drop these row indexes from dataFrame 
cities_humidity_le_100_df.drop(index_names, inplace = True) 
cities_humidity_le_100_df
# Out:
#      City ID            City  Cloudiness Country        Date  Humidity  \
# 0    2008303       busselton          81      AU  1612595343        99
# 1       1399       liverpool          90      GB  1612595343        60
# 2       1966      bredasdorp           7      ZA  1612595343        77
# 3    2006131        hermanus           4      ZA  1612595343        90
# 4       8491       coihaique           0      CL  1612595343        35
# ..       ...             ...         ...     ...         ...       ...
# 254     4061    fayetteville           1      US  1612595343        81
# 255     2047           mbini          20      GQ  1612595343       100
# 256     9038  kamskoye ustye          75      RU  1612595343        71
# 257      900     beaverlodge          40      CA  1612595343        68
# 258     9496         ballina          72      AU  1612595343        57
#
#          Lat       Lng  Max Temp  Wind Speed
# 0   -33.6500  115.3333    64.994        0.89
# 1    53.4106   -2.9779    35.600        7.72
# 2   -34.5322   20.0403    59.000        2.57
# 3   -34.4187   19.2345    57.002        0.71
# 4   -45.5752  -72.0662    71.600        3.09
# ..       ...       ...       ...         ...
# 254  35.0527  -78.8784    41.000        1.70
# 255   1.5740    9.6134    78.800        3.39
# 256  55.2016   49.2680    -7.600        8.00
# 257  55.2166 -119.4361   -25.600        0.24
# 258 -28.8667  153.5667    80.600        8.75
#
# [259 rows x 10 columns]

# %%
# Get the indices of cities that have humidity over 100%.
index_cities_humid_over100 = cities_df[ cities_df['Humidity'] > 100].index 
index_cities_humid_over100
# Out:
# Int64Index([], dtype='int64')

# %%
cities_df[ cities_df['Humidity'] > 100]
# Out:
# Empty DataFrame
# Columns: [City ID, City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
#### DO NOT RUN -- display for sample reference only

# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
#cities_df['Date'][0].Date(levels(data$x), format="%d.%m.%Y")
#cities_df['Date'][0].Date(1612595343, format="%d.%m.%Y")
#x=cities_df['Date'][0]
#x
date='04/01/20'

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# # Latitude vs Temperature Plot

# %%
#### scatter plot using pandas --LATITUDE vs TEMPERATURE

cities_df.plot(kind="scatter", x='Lat', y='Max Temp')

plt.title("City Latitude vs Max Temperature <date>")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/Lat_vs_Temp_plot.png")

#plt.legend()
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %% [markdown]
# # Latitude vs Humidity Plot

# %%
#### scatter plot using pandas --

cities_df.plot(kind="scatter", x='Lat', y='Humidity')

# Set a Title and labels
plt.title("City Latitude vs Humidity <date>")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/Lat_vs_Humidity_plot.png")

#plt.legend()
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %% [markdown]
# # Latitude vs Cloudiness Plot

# %%
#### scatter plot using pandas -- Latitude vs Cloudiness

cities_df.plot(kind="scatter", x='Lat', y='Cloudiness')

# Set a Title and labels
plt.title("City Latitude vs Cloudiness <date>")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/Lat_vs_Cloudiness_plot.png")

#plt.legend()
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %% [markdown]
# # Latitude vs Wind Speed Plot

# %%
#### scatter plot using pandas --

cities_df.plot(kind="scatter", x='Lat', y='Wind Speed')

# Set a Title and labels
plt.title("City Latitude vs Wind Speed <date>")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/Lat_vs_WindSpeed_plot.png")

#plt.legend()
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %% [markdown]
# # Northern Hemisphere & Southern Hemisphere
#
# #### Northern Hemipshere:  >= 0 degrees latitude
# #### Southern Hemisphere:   < 0 degrees latitude

# %%
nor_hem_df=cities_df[ cities_df['Lat'] >= 0]
nor_hem_df
# Out:
#      City ID            City  Cloudiness Country        Date  Humidity  \
# 1       1399       liverpool          90      GB  1612595343        60
# 5       4742       lancaster           1      US  1612595343        47
# 6       7881            hilo          20      US  1612595343        54
# 7       1663    longyearbyen           0      SJ  1612595343        48
# 8       7597         baghdad           0      IQ  1612595343        94
# ..       ...             ...         ...     ...         ...       ...
# 253     7955          hasaki          75      JP  1612595343        52
# 254     4061    fayetteville           1      US  1612595343        81
# 255     2047           mbini          20      GQ  1612595343       100
# 256     9038  kamskoye ustye          75      RU  1612595343        71
# 257      900     beaverlodge          40      CA  1612595343        68
#
#          Lat       Lng  Max Temp  Wind Speed
# 1    53.4106   -2.9779      35.6        7.72
# 5    40.2504  -76.2499      32.0        7.20
# 6    19.7297 -155.0900      80.6        5.66
# 7    78.2186   15.6401      14.0        8.75
# 8    33.3406   44.4009      53.6        1.03
# ..       ...       ...       ...         ...
# 253  35.7333  140.8333      41.0        3.09
# 254  35.0527  -78.8784      41.0        1.70
# 255   1.5740    9.6134      78.8        3.39
# 256  55.2016   49.2680      -7.6        8.00
# 257  55.2166 -119.4361     -25.6        0.24
#
# [176 rows x 10 columns]

# %%
sou_hem_df=cities_df[ cities_df['Lat'] <= 0]
sou_hem_df
# Out:
#      City ID            City  Cloudiness Country        Date  Humidity  \
# 0    2008303       busselton          81      AU  1612595343        99
# 2       1966      bredasdorp           7      ZA  1612595343        77
# 3    2006131        hermanus           4      ZA  1612595343        90
# 4       8491       coihaique           0      CL  1612595343        35
# 9       9574  howard springs          75      AU  1612595343        78
# ..       ...             ...         ...     ...         ...       ...
# 234     9600          sidney          75      AU  1612595343        78
# 241  2002134  cap malheureux          45      MU  1612595343        84
# 245     7317         isangel          40      VU  1612595343        74
# 249  2016451       concordia           0      AR  1612595343        64
# 258     9496         ballina          72      AU  1612595343        57
#
#          Lat       Lng  Max Temp  Wind Speed
# 0   -33.6500  115.3333    64.994        0.89
# 2   -34.5322   20.0403    59.000        2.57
# 3   -34.4187   19.2345    57.002        0.71
# 4   -45.5752  -72.0662    71.600        3.09
# 9   -12.4970  131.0470    82.994        5.14
# ..       ...       ...       ...         ...
# 234 -33.8679  151.2073    69.998        7.72
# 241 -19.9842   57.6142    78.008        1.34
# 245 -19.5500  169.2667    84.200        3.09
# 249 -31.3930  -58.0209    80.006        1.28
# 258 -28.8667  153.5667    80.600        8.75
#
# [83 rows x 10 columns]

# %%
# Latitude vs. Temperature Plot -- All Latitudes
lat=cities_df['Lat']
lat
# Out:
# 0     -33.6500
# 1      53.4106
# 2     -34.5322
# 3     -34.4187
# 4     -45.5752
#         ...
# 254    35.0527
# 255     1.5740
# 256    55.2016
# 257    55.2166
# 258   -28.8667
# Name: Lat, Length: 259, dtype: float64

# %%
# split for Northern Hemisphere & Southern Hemisphere
n_lat = nor_hem_df['Lat']
n_lat
# Out:
# 1      53.4106
# 5      40.2504
# 6      19.7297
# 7      78.2186
# 8      33.3406
#         ...
# 253    35.7333
# 254    35.0527
# 255     1.5740
# 256    55.2016
# 257    55.2166
# Name: Lat, Length: 176, dtype: float64

# %%
# get latitude min & max for x axis
min_n_lat = n_lat.min()
min_n_lat
# Out:
# 1.55

# %%
max_n_lat = n_lat.max()
max_n_lat
# Out:
# 78.2186

# %%
# split for Northern Hemisphere & Southern Hemisphere
s_lat = sou_hem_df['Lat']
s_lat
# Out:
# 0     -33.6500
# 2     -34.5322
# 3     -34.4187
# 4     -45.5752
# 9     -12.4970
#         ...
# 234   -33.8679
# 241   -19.9842
# 245   -19.5500
# 249   -31.3930
# 258   -28.8667
# Name: Lat, Length: 83, dtype: float64

# %%
# get latitude min & max for x axis
min_s_lat = s_lat.min()
min_s_lat
# Out:
# -54.8

# %%
max_s_lat = s_lat.max()
max_s_lat
# Out:
# -0.7393

# %%
n_temp=nor_hem_df['Max Temp']
n_temp
# Out:
# 1      35.6
# 5      32.0
# 6      80.6
# 7      14.0
# 8      53.6
#        ...
# 253    41.0
# 254    41.0
# 255    78.8
# 256    -7.6
# 257   -25.6
# Name: Max Temp, Length: 176, dtype: float64

# %%
# get Temperature min & max for y axis -- NORTHERN HEMISPHERE
min_n_temp = n_temp.min()
min_n_temp
# Out:
# -45.39999999999995

# %%
max_n_temp = n_temp.max()
max_n_temp
# Out:
# 89.6

# %%
# get Temperature min & max for y axis -- SOUTHERN HEMISPHERE
s_temp=sou_hem_df['Max Temp']
s_temp
# Out:
# 0      64.994
# 2      59.000
# 3      57.002
# 4      71.600
# 9      82.994
#         ...
# 234    69.998
# 241    78.008
# 245    84.200
# 249    80.006
# 258    80.600
# Name: Max Temp, Length: 83, dtype: float64

# %%
# get Temperatrue min & max for y axis
min_s_temp = s_temp.min()
min_s_temp
# Out:
# 51.8

# %%
max_s_temp = s_temp.max()
max_s_temp
# Out:
# 89.6

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# -- CAN BE DELETED

# Create Scatter Pot -- Northern vs. Temperature Plot

# enable matplotlib so that the correlation / regression line can be drawn over the scatter plot

# %matplotlib notebook 

#----------------------------------------------
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

from scipy.stats import sem

#----------------------------------------------

# variables for chart data
x_data = n_lat  # Northern Hemisphere

y_data = nor_hem_df['Max Temp']

#----------------------------------------------

# The maximum x value 
x_limit = max_n_lat

# List of values 
x_axis = np.arange(min_n_lat, x_limit, 2)

# Create a random array of data that we will use for our y values
#data = [random.random() for value in x_axis]

# Tells matplotlib to create a scatter plot
# The size of each point on our plot is determined by their x value

plt.scatter(x_data, y_data, marker="o", facecolors="blue", edgecolors="black", s=y_data, alpha=0.75)
            
# x limits of scatter plot
plt.xlim(min_n_lat-10, max_n_lat+10)   

# y limits of scatter plot
plt.ylim(min_n_temp-10, max_n_temp+10)

# Set a Title and labels
plt.title("Northern Hemisphere - Latitude vs Max Temperature <date>")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/N_Lat_vs_Temp_plot.png")

plt.show()

#plt.close

# %%
# create the scatter plot - line -- Northern Hemisphere
# Dependencies

from matplotlib import pyplot as plt
from scipy.stats import linregress
from sklearn import datasets
from scipy.stats import sem

import numpy as np
import pandas as pd

lats = n_lat
temps = nor_hem_df['Max Temp']

correlation = st.pearsonr(lats, temps)
correlation
# Out:
# (-0.8099885696128657, 3.490696595147158e-42)

# %%
# Add the linear regression equation and line to plot
x_values = n_lat
y_values = nor_hem_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Set a Title and labels
plt.title("Northern Hemisphere - Max Temp vs Latitude Linear Regression" + date)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("Images/N_Lat_vs_Temp_with_line_plot.png")

plt.show()

# %% [markdown]
# ### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## DELETE

# Create Scatter Pot -- Southern vs. Temperature Plot

# enable matplotlib so that the correlation / regression line can be drawn over the scatter plot

# %matplotlib notebook 

#----------------------------------------------
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

from scipy.stats import sem

#----------------------------------------------

# variables for chart data
x_data = s_lat  
y_data = sou_hem_df['Max Temp']

#----------------------------------------------

# The maximum x value 
x_limit = max_s_lat

# List of values 
x_axis = np.arange(min_s_lat, x_limit, 2)

# Create a random array of data that we will use for our y values
#data = [random.random() for value in x_axis]

# Tells matplotlib to create a scatter plot
# The size of each point on our plot is determined by their x value

plt.scatter(x_data, y_data, marker="o", facecolors="blue", edgecolors="black", s=y_data, alpha=0.75)
            
# x limits of scatter plot
plt.xlim(min_s_lat-10, max_s_lat+10)   

# y limits of scatter plot
plt.ylim(min_s_temp-10, max_s_temp+10)

# Set a Title and labels
plt.title("Southern Hemisphere - Latitude vs Max Temperature " + date)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/S_Lat_vs_Temp_plot.png")

plt.show()

#plt.close

# %%
#create the scatter plot - line -- Northern Hemisphere
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
from sklearn import datasets
from scipy.stats import sem

import numpy as np
import pandas as pd

lats = s_lat
temps = sou_hem_df['Max Temp']

correlation = st.pearsonr(lats, temps)
correlation
# Out:
# (0.6467788839361903, 3.964785217720794e-11)

# %%
# Add the linear regression equation and line to plot
x_values = s_lat
y_values = sou_hem_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Set a Title and labels
plt.title("Southern Hemisphere - Max Temp vs Latitude Linear Regression " + date)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("Images/N_Lat_vs_Temp_with_line_plot.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#### reference only for expected results

# %%
# create the scatter plot for Latitude vs. Humidity Plot

# %%
#### scatter plot using pandas -- ALL CITIES

cities_df.plot(kind="scatter", x='Lat', y='Humidity')

# Set a Title and labels
plt.title("City Latitude vs Humidity <date>")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/Lat_vs_Humidity_plot.png")

#plt.legend()
plt.close

# %%
temp_hum=cities_df['Humidity']
temp_hum

# %%
# get Temperatrue min & max for y axis
min_humidity = temp_hum.min()
min_humidity

# %%
max_humidity = temp_hum.max()
max_humidity

# %%
# Create Scatter Pot -- Latitude vs. Humidity Plot

# enable matplotlib so that the correlation / regression line can be drawn over the scatter plot

# %matplotlib notebook 

#----------------------------------------------
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

from scipy.stats import sem
#----------------------------------------------

# variables for chart data
x_data = cities_df['Lat']
y_data = cities_df['Humidity']

#----------------------------------------------

# The maximum x value for our chart will be 25
x_limit = max_lat

# List of values 
x_axis = np.arange(min_lat, x_limit, 2)

# Create a random array of data that we will use for our y values
#data = [random.random() for value in x_axis]

# Tells matplotlib to create a scatter plot
# The size of each point on our plot is determined by their x value

plt.scatter(x_data, y_data, marker="o", facecolors="blue", edgecolors="black", s=y_data, alpha=0.75)
            
# x limits of scatter plot
plt.xlim(min_lat-0.5, max_lat+0.9)   

# y limits of scatter plot
plt.ylim(min_humidity-0.1, max_humidity+10)

# Set a Title and labels
plt.title("City Latitude vs Humidity <date>")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# tigh_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/Lat_vs_Humidity_plot.png")

plt.show()

#plt.close

# %% [markdown]
# #### Nothern Hemisphere Humidity

# %%
temp_nor_hum = nor_hem_df['Humidity']
temp_nor_hum
# Out:
# 1       60
# 5       47
# 6       54
# 7       48
# 8       94
#       ...
# 253     52
# 254     81
# 255    100
# 256     71
# 257     68
# Name: Humidity, Length: 176, dtype: int64

# %%
# get Temperatrue min & max for y axis
min_nor_humidity = temp_nor_hum.min()
min_nor_humidity
# Out:
# 7

# %%
max_nor_humidity = temp_nor_hum.max()
max_nor_humidity
# Out:
# 100

# %% [markdown]
# #### Southern Hemisphere Humidity

# %%
temp_sou_hum = sou_hem_df['Humidity']
temp_sou_hum
# Out:
# 0      99
# 2      77
# 3      90
# 4      35
# 9      78
#        ..
# 234    78
# 241    84
# 245    74
# 249    64
# 258    57
# Name: Humidity, Length: 83, dtype: int64

# %%
# get Temperatrue min & max for y axis
min_sou_humidity = temp_sou_hum.min()
min_sou_humidity
# Out:
# 21

# %%
max_sou_humidity = temp_sou_hum.max()
max_sou_humidity
# Out:
# 100

# %%
#### Humidity (%) vs. Latitude Linear Regression

# %%
## for ALL CITIES

# %%
#create the scatter plot - line
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

lats = cities_df['Lat']
hums = cities_df['Humidity']

correlation = st.pearsonr(lats, hums)
correlation

# %%
# Add the linear regression equation and line to plot
x_values = cities_df['Lat']
y_values = cities_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Set a Title and labels
plt.title("City Latitude vs Humidity " + date)
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.savefig("Images/Lat_vs_Humidity_with_line_plot.png")

plt.show()

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#create the scatter plot - line -- Northern Hemisphere
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
from sklearn import datasets
from scipy.stats import sem

import numpy as np
import pandas as pd

lats = n_lat
hums = nor_hem_df['Humidity']

correlation = st.pearsonr(lats, hums)
correlation
# Out:
# (-0.13917236446811798, 0.06545333284526673)

# %%
# Add the linear regression equation and line to plot
x_values = n_lat
y_values = nor_hem_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Set a Title and labels
plt.title("Northern Hemisphere - Humidity vs Latitude Linear Regression " + date)
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.savefig("Images/N_Lat_vs_Humidity_with_line_plot.png")

plt.show()

# %%
print("The r-value: is: ", rvalue)
# Out:
# The r-value: is:  0.6467788839361902

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#create the scatter plot - line -- Northern Hemisphere
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
from sklearn import datasets
from scipy.stats import sem

import numpy as np
import pandas as pd

lats = s_lat
hums = sou_hem_df['Humidity']

correlation = st.pearsonr(lats, hums)
correlation
# Out:
# (0.37950185154920346, 0.00040265769424315597)

# %%
# Add the linear regression equation and line to plot
x_values = s_lat
y_values = sou_hem_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Set a Title and labels
plt.title("Southern Hemisphere - Humidity vs Latitude Linear Regression " + date)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
 
plt.savefig("Images/S_Lat_vs_Humidity_with_line_plot.png")

plt.show()

# %%
line_eq
# Out:
# 'y = 0.48x + 86.17'

# %%
print("The r-value: is: ", rvalue)
# Out:
# The r-value: is:  0.3795018515492035

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
nor_hem_df.columns
# Out:
# Index(['City ID', 'City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat',
#        'Lng', 'Max Temp', 'Wind Speed'],
#       dtype='object')

# %%
#create the scatter plot - line -- Northern Hemisphere
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
from sklearn import datasets
from scipy.stats import sem

import numpy as np
import pandas as pd

lats = n_lat
clouds = nor_hem_df['Cloudiness']

correlation = st.pearsonr(lats, clouds)
correlation
# Out:
# (0.1871452037943618, 0.012879489197498711)

# %%
# Add the linear regression equation and line to plot
x_values = n_lat
y_values = nor_hem_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Set a Title and labels
plt.title("Northern Hemisphere - Cloudines (%) vs Latitude Linear Regression " + date)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.savefig("Images/N_Cloudat_vs_Humidity_with_line_plot.png")

plt.show()

# %%
print("The r-value: is: ", rvalue)
# Out:
# The r-value: is:  0.18714520379436156

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#create the scatter plot - line -- Southern Hemisphere
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
from sklearn import datasets
from scipy.stats import sem

import numpy as np
import pandas as pd

lats = s_lat
clouds = sou_hem_df['Cloudiness']

correlation = st.pearsonr(lats, clouds)
correlation
# Out:
# (-0.003383505747334658, 0.9757817002900567)

# %%
# Add the linear regression equation and line to plot
x_values = s_lat
y_values = sou_hem_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Set a Title and labels
plt.title("Southern Hemisphere - Cloudines (%) vs Latitude Linear Regression " + date)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.savefig("Images/N_Cloud_vs_Humidity_with_line_plot.png")

plt.show()

# %%
print("The r-value: is: ", rvalue)
# Out:
# The r-value: is:  -0.0033835057473346713

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#create the scatter plot - line -- Northern Hemisphere
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
from sklearn import datasets
from scipy.stats import sem

import numpy as np
import pandas as pd

lats = n_lat
winds = nor_hem_df['Wind Speed']

correlation = st.pearsonr(lats, winds)
correlation
# Out:
# (0.19719943394055056, 0.008707848435450052)

# %%
# Add the linear regression equation and line to plot
x_values = n_lat
y_values = nor_hem_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Set a Title and labels
plt.title("Northern Hemisphere - Wind Speed (mph) vs Latitude Linear Regression " + date)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("Images/N_WindSpeed_vs_Lat_with_line_plot.png")

plt.show()

# %%
print("The r-value: is: ", rvalue)
# Out:
# The r-value: is:  0.19719943394055064

# %% [markdown]
# #### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#create the scatter plot - line -- Northern Hemisphere
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
from sklearn import datasets
from scipy.stats import sem

import numpy as np
import pandas as pd

lats = s_lat
winds = sou_hem_df['Wind Speed']

correlation = st.pearsonr(lats, winds)
correlation
# Out:
# (-0.24271475549931523, 0.027044547050811517)

# %%
# Add the linear regression equation and line to plot
x_values = s_lat
y_values = sou_hem_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Set a Title and labels
plt.title("Southern Hemisphere - Wind Speed (mph) vs Latitude Linear Regression " + date)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.savefig("Images/N_WindSpeed_vs_Lat_with_line_plot.png")

plt.show()

# %%
print("The r-value: is: ", rvalue)
# Out:
# The r-value: is:  -0.24271475549931526

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#### reference only for expected results

# %%
# create the scatter plot for Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
temp=cities_df['Cloudiness']
temp

# %%
# get Cloudiness min & max for x/y axis
min_cloudiness = temp.min()
min_cloudiness

# %%
# get Cloudiness for x/y axis
max_cloudiness = temp.max()
max_cloudiness

# %%
#### scatter plot using pandas --

cities_df.plot(kind="scatter", x='Lat', y='Cloudiness')

# Set a Title and labels
plt.title("City Latitude vs Cloudiness", date)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/Lat_vs_Cloudiness_plot.png")

#plt.legend()
plt.close

# %%
# Create Scatter Pot -- Latitude vs. Cloudiness Plot

# enable matplotlib so that the correlation / regression line can be drawn over the scatter plot

# %matplotlib notebook 

#----------------------------------------------
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

from scipy.stats import sem
#----------------------------------------------

# variables for chart data
x_data = cities_df['Lat']
y_data = cities_df['Cloudiness']

#----------------------------------------------

# The maximum x value for our chart will be 25
x_limit = lat_max

# List of values 
x_axis = np.arange(0, x_limit, 2)

# Create a random array of data that we will use for our y values
#data = [random.random() for value in x_axis]

# Tells matplotlib to create a scatter plot
# The size of each point on our plot is determined by their x value

plt.scatter(x_data, y_data, marker="o", facecolors="blue", edgecolors="black", s=y_data, alpha=0.75)
            
# x limits of scatter plot
plt.xlim(min_lat-5, max_lat+5)   

# y limits of scatter plot
plt.ylim(min_cloudiness-10, max_cloudiness+10)

# Set a Title and labels
plt.title("City Latitude vs Cloudiness <date>")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/Lat_vs_Cloudiness_plot.png")

plt.show()

#plt.close

# %%
#create the scatter plot - line
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

lats = cities_df['Lat']
hums = cities_df['Cloudiness']

correlation = st.pearsonr(lats, hums)
correlation

# %%
# Add the linear regression equation and line to plot
x_values = cities_df['Lat']
y_values = cities_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Set a Title and labels
plt.title("City Latitude vs Cloudiness <date>")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.savefig("Images/Lat_vs_Cloudiness_with-line_plot.png")

plt.show()

# %%
#### reference only for expected results

# %%
# create the scatter plot for Latitude vs. Wind Speed Plot

# %%
#### scatter plot using pandas --

cities_df.plot(kind="scatter", x='Lat', y='Wind Speed')

# Set a Title and labels
plt.title("City Latitude vs Wind Speed <date>")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# tight_layout() adjusts the visual of our graph making it easier to see
plt.tight_layout()

# Save our graph and show the graph
# plt.savefig("../Images/<xyz.png")

plt.savefig("Images/Lat_vs_WindSpeed_plot.png")

#plt.legend()
plt.close

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#### reference only for expected results

# %%
# create the Linear Regression -- Northern Hemisphere - Max Temp vs. Latitude Linear Regression¶

# %% [markdown]
# ## Linear Regression

# %%
#### reference only for expected results

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#### reference only for expected results

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#### reference only for expected results

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#### reference only for expected results

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#### reference only for expected results

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#### reference only for expected results

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#### reference only for expected results

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#### reference only for expected results

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#### reference only for expected results
